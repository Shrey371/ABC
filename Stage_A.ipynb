# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrey371/ABC/blob/main/Stage_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Shrey371/ABC/main/FoodBalanceSheets_E_Africa_NOFLAG.csv'
df = pd.read_csv(url, encoding = "ISO-8859-1")
# Dataset is now stored in a Pandas Dataframe

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.Area.nunique(dropna = True)
# Out:
# 49

# %%
df.shape
# Out:
# (60943, 12)

# %%
df["Y2015"].mean()
# Out:
# 135.23596649549626

# %%
df["Y2015"].std()
# Out:
# 1603.4039839425013

# %%
c = df.groupby(['Y2015', 'Y2018'])['Item'].sum()
#c.loc[c['Item'] == 'Wine']
c
# Out:
# Y2015      Y2018
# -3161.0    -296.0       Cereals - Excluding Beer
# -2152.0    -597.0             Maize and products
# -1284.0     1898.0      Cereals - Excluding Beer
# -907.0     -529.0       Cereals - Excluding Beer
# -887.0      163.0           Sorghum and products
#                                   ...
#  92443.0    98424.0                   Population
#  100835.0   109224.0                  Population
#  110798.0   117038.0               Starchy Roots
#  111663.0   118172.0               Starchy Roots
#  181137.0   195875.0                  Population
# Name: Item, Length: 14814, dtype: object

# %%
df.groupby(['Y2017', 'Area'])
# Out:
# <bound method GroupBy.describe of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7fdc2fc72310>>

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
y[1][1]
# Out:
# 8

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df['Y2014'].isna().sum()
# Out:
# 1589

# %%
df3 = df.groupby('Element')
df3.get_group('Processing')
# Out:
#        Area Code      Area  Item Code                      Item  Element Code  \
# 19             4   Algeria       2905  Cereals - Excluding Beer          5131
# 35             4   Algeria       2511        Wheat and products          5131
# 51             4   Algeria       2805         Rice and products          5131
# 66             4   Algeria       2513       Barley and products          5131
# 81             4   Algeria       2514        Maize and products          5131
# ...          ...       ...        ...                       ...           ...
# 60694        181  Zimbabwe       2946               Animal fats          5131
# 60717        181  Zimbabwe       2743                     Cream          5131
# 60730        181  Zimbabwe       2737        Fats, Animals, Raw          5131
# 60789        181  Zimbabwe       2948   Milk - Excluding Butter          5131
# 60803        181  Zimbabwe       2848   Milk - Excluding Butter          5131
#
# ...

# %%
df.groupby('Element').mean().add_prefix('mean_')
# Out:
#                                         mean_Area Code  mean_Item Code  \
# Element
# Domestic supply quantity                    133.898584     2681.292729
# Export Quantity                             136.250284     2689.201226
# Fat supply quantity (g/capita/day)          134.391798     2694.604818
# Feed                                        133.640637     2682.719484
# Food                                        134.243068     2688.734062
# Food supply (kcal/capita/day)               134.434982     2694.666933
# Food supply quantity (kg/capita/yr)         134.239755     2688.155148
# Import Quantity                             133.912045     2684.562366
# Losses                                      136.561971     2700.250373
# Other uses (non-food)                       136.001155     2730.801963
# Processing                                  135.293532     2661.898507
# Production                                  135.725586     2692.618655
# ...
